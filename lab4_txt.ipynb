# %%
import re
f = open("row.txt")
pattern = re.compile(r".*аб*.*")
for i in f.readlines():
    for j in i.split():
        print(j)
        match = pattern.match(j)
        if match: print(match.group())
        else: print("No such word")
# Out:
# ДУБЛИКАТ
# No such word
# Филиал
# Филиал
# ТОО
# No such word
# EUROPHARMA
# No such word
# Астана
# Астана
# БИН
# No such word
# 080841000761
# No such word
# НДС
# No such word
# Серия
# No such word
# 58001
# No such word
# №
# No such word
# 0014377
# No such word
# Касса
# Касса
# 300-189
# No such word
# Смена
# Смена
# 10
# No such word
# Порядковый
# No such word
# номер
# No such word
# чека
# чека
# №64
# No such word
# Чек
# No such word
# №2331180266
# No such word
# Кассир
# Кассир
# Аптека
# Аптека
# 17-1
# No such word
# ПРОДАЖА
# No such word
# 1.
# No such word
# Натрия
# Натрия
# хлорид
# No such word
# 0,9%,
# No such word
# 200
# No such word
# мл,
# No such word
# фл
# No such word
# 2,000
# No such word
# x
# No such word
# 154,00
# No such word
# 308,00
# No such word
# Стоимость
# No such word
# 308,00
# No such word
# 2.
# No such word
# Борный
# No such word
# спирт
# No such word
# 3%,
# No such word
# 20
# No such word
# мл,
# No such word
# фл.
# No such word
# 1,000
# No such word
# x
# No such word
# 51,00
# No such word
# 51,00
# No such word
# Стоимость
# No such word
# 51,00
# No such word
# 3.
# No such word
# Шприц
# No such word
# 2
# No such word
# мл,
# No such word
# 3-х
# No such word
# комп.
# No such word
# (Bioject)
# No such word
# 2,000
# No such word
# x
# No such word
# 16,00
# No such word
# 32,00
# No such word
# Стоимость
# No such word
# 32,00
# No such word
# 4.
# No such word
# Система
# Система
# для
# No such word
# инфузии
# No such word
# Vogt
# No such word
# Medical
# No such word
# 2,000
# No such word
# x
# No such word
# 60,00
# No such word
# 120,00
# No such word
# Стоимость
# No such word
# 120,00
# No such word
# 5.
# No such word
# Naturella
# No such word
# прокладки
# прокладки
# Классик
# Классик
# макси
# макси
# №8
# No such word
# 1,000
# No such word
# x
# No such word
# 310,00
# No such word
# 310,00
# No such word
# Стоимость
# No such word
# 310,00
# No such word
# 6.
# No such word
# AURA
# No such word
# Ватные
# Ватные
# диски
# No such word
# №150
# No such word
# 1,000
# No such word
# x
# No such word
# 461,00
# No such word
# 461,00
# No such word
# Стоимость
# No such word
# 461,00
# No such word
# 7.
# No such word
# Чистая
# Чистая
# линия
# No such word
# скраб
# скраб
# мягкий
# No such word
# 50
# No such word
# мл
# No such word
# 1,000
# No such word
# x
# No such word
# 381,00
# No such word
# 381,00
# No such word
# Стоимость
# No such word
# 381,00
# No such word
# 8.
# No such word
# Чистая
# Чистая
# линия
# No such word
# скраб
# скраб
# очищающийабрикос
# очищающийабрикос
# 50
# No such word
# мл
# No such word
# 1,000
# No such word
# x
# No such word
# 386,00
# No such word
# 386,00
# No such word
# Стоимость
# No such word
# 386,00
# No such word
# 9.
# No such word
# Чистая
# Чистая
# линия
# No such word
# скраб
# скраб
# мягкий
# No such word
# 50
# No such word
# мл
# No such word
# 1,000
# No such word
# x
# No such word
# 381,00
# No such word
# 381,00
# No such word
# Стоимость
# No such word
# 381,00
# No such word
# 10.
# No such word
# Carefree
# No such word
# салфетки
# салфетки
# Алоэвоздухопроницаемые
# Алоэвоздухопроницаемые
# №20
# No such word
# 1,000
# No such word
# x
# No such word
# 414,00
# No such word
# 414,00
# No such word
# Стоимость
# No such word
# 414,00
# No such word
# 11.
# No such word
# Pro
# No such word
# Series
# No such word
# Шампунь
# Шампунь
# яркий
# No such word
# цвет
# No such word
# 500мл
# No such word
# 1,000
# No such word
# x
# No such word
# 841,00
# No such word
# 841,00
# No such word
# Стоимость
# No such word
# 841,00
# No such word
# 12.
# No such word
# Pro
# No such word
# Series
# No such word
# бальзам-ополаскивательдля
# бальзам-ополаскивательдля
# длител
# No such word
# ухода
# ухода
# за
# за
# окрашеннымиволосами
# окрашеннымиволосами
# Яркий
# No such word
# цвет
# No such word
# 500мл
# No such word
# 1,000
# No such word
# x
# No such word
# 841,00
# No such word
# 841,00
# No such word
# Стоимость
# No such word
# 841,00
# No such word
# 13.
# No such word
# Clear
# No such word
# шампунь
# шампунь
# Актив
# No such word
# спорт
# No such word
# 2в1мужской
# No such word
# 400
# No such word
# мл
# No such word
# 1,000
# No such word
# x
# No such word
# 1
# No such word
# 200,00
# No such word
# 1
# No such word
# 200,00
# No such word
# Стоимость
# No such word
# 1
# No such word
# 200,00
# No such word
# 14.
# No such word
# Bio
# No such word
# World
# No such word
# (HYDRO
# No such word
# THERAPY)Мицеллярная
# THERAPY)Мицеллярная
# вода
# вода
# 5в1,
# No such word
# 445мл
# No such word
# 1,000
# No such word
# x
# No such word
# 1
# No such word
# 152,00
# No such word
# 1
# No such word
# 152,00
# No such word
# Стоимость
# No such word
# 1
# No such word
# 152,00
# No such word
# 15.
# No such word
# Bio
# No such word
# World
# No such word
# (HYDRO
# No such word
# THERAPY)
# No such word
# Гель-муссдля
# No such word
# умывания
# умывания
# с
# No such word
# гиалуроновойкислотой,
# гиалуроновойкислотой,
# 250мл
# No such word
# 1,000
# No such word
# x
# No such word
# 1
# No such word
# 152,00
# No such word
# 1
# No such word
# 152,00
# No such word
# Стоимость
# No such word
# 1
# No such word
# 152,00
# No such word
# 16.
# No such word
# [RX]-Натрия
# [RX]-Натрия
# хлорид
# No such word
# 0,9%,
# No such word
# 100
# No such word
# мл,
# No such word
# фл.
# No such word
# 1,000
# No such word
# x
# No such word
# 168,00
# No such word
# 168,00
# No such word
# Стоимость
# No such word
# 168,00
# No such word
# 17.
# No such word
# [RX]-Дисоль
# No such word
# р-р
# No such word
# 400
# No such word
# мл,
# No such word
# фл.
# No such word
# 1,000
# No such word
# x
# No such word
# 163,00
# No such word
# 163,00
# No such word
# Стоимость
# No such word
# 163,00
# No such word
# 18.
# No such word
# Тагансорбент
# Тагансорбент
# с
# No such word
# иономи
# No such word
# серебра
# серебра
# №30,пор.
# No such word
# 1,000
# No such word
# x
# No such word
# 1
# No such word
# 526,00
# No such word
# 1
# No such word
# 526,00
# No such word
# Стоимость
# No such word
# 1
# No such word
# 526,00
# No such word
# 19.
# No such word
# [RX]-Церукал
# [RX]-Церукал
# 2%,
# No such word
# 2
# No such word
# мл,
# No such word
# №10,
# No such word
# амп.
# амп.
# 2,000
# No such word
# x
# No such word
# 396,00
# No such word
# 792,00
# No such word
# Стоимость
# No such word
# 792,00
# No such word
# 20.
# No such word
# [RX]-Андазол
# [RX]-Андазол
# 200
# No such word
# мг,
# No such word
# №40,
# No such word
# табл.
# табл.
# 1,000
# No such word
# x
# No such word
# 7
# No such word
# 330,00
# No such word
# 7
# No such word
# 330,00
# No such word
# Стоимость
# No such word
# 7
# No such word
# 330,00
# No such word
# Банковская
# Банковская
# карта:
# карта:
# 18
# No such word
# 009,00
# No such word
# ИТОГО:
# No such word
# 18
# No such word
# 009,00
# No such word
# в
# No such word
# т.ч.
# No such word
# НДС
# No such word
# 12%:
# No such word
# 0,00
# No such word
# Фискальный
# Фискальный
# признак:
# признак:
# 2331180266
# No such word
# Время:
# No such word
# 18.04.2019
# No such word
# 11:13:58
# No such word
# г.
# No such word
# Нур-султан,Казахстан,
# Нур-султан,Казахстан,
# Мангилик
# Мангилик
# Ел,19,
# No such word
# нп-5
# No such word
# Оператор
# Оператор
# фискальных
# фискальных
# данных:
# данных:
# АО"Казахтелеком"Для
# АО"Казахтелеком"Для
# проверки
# No such word
# чека
# чека
# зайдите
# зайдите
# на
# на
# сайт:consumer.oofd.kz
# сайт:consumer.oofd.kz
# ФИСКАЛЬНЫЙ
# No such word
# ЧЕК
# No such word
# ФП
# No such word
# ИНК
# No such word
# ОФД:
# No such word
# 311559
# No such word
# Код
# No such word
# ККМ
# No such word
# КГД
# No such word
# (РНМ):
# No such word
# 620300145316
# No such word
# ЗНМ:
# No such word
# SWK00034961
# No such word
# WEBKASSA.KZ
# No such word
# аб
# аб

# %%
import re
f = open("row.txt")
pattern = re.compile(r".*аб{2,3}.*")
for i in f.readlines():
    for j in i.split():
        print(j)
        match = pattern.match(j)
        if match: print(match.group())
        else: print("No such word")
# Out:
# ДУБЛИКАТ
# No such word
# Филиал
# No such word
# ТОО
# No such word
# EUROPHARMA
# No such word
# Астана
# No such word
# БИН
# No such word
# 080841000761
# No such word
# НДС
# No such word
# Серия
# No such word
# 58001
# No such word
# №
# No such word
# 0014377
# No such word
# Касса
# No such word
# 300-189
# No such word
# Смена
# No such word
# 10
# No such word
# Порядковый
# No such word
# номер
# No such word
# чека
# No such word
# №64
# No such word
# Чек
# No such word
# №2331180266
# No such word
# Кассир
# No such word
# Аптека
# No such word
# 17-1
# No such word
# ПРОДАЖА
# No such word
# 1.
# No such word
# Натрия
# No such word
# хлорид
# No such word
# 0,9%,
# No such word
# 200
# No such word
# мл,
# No such word
# фл
# No such word
# 2,000
# No such word
# x
# No such word
# 154,00
# No such word
# 308,00
# No such word
# Стоимость
# No such word
# 308,00
# No such word
# 2.
# No such word
# Борный
# No such word
# спирт
# No such word
# 3%,
# No such word
# 20
# No such word
# мл,
# No such word
# фл.
# No such word
# 1,000
# No such word
# x
# No such word
# 51,00
# No such word
# 51,00
# No such word
# Стоимость
# No such word
# 51,00
# No such word
# 3.
# No such word
# Шприц
# No such word
# 2
# No such word
# мл,
# No such word
# 3-х
# No such word
# комп.
# No such word
# (Bioject)
# No such word
# 2,000
# No such word
# x
# No such word
# 16,00
# No such word
# 32,00
# No such word
# Стоимость
# No such word
# 32,00
# No such word
# 4.
# No such word
# Система
# No such word
# для
# No such word
# инфузии
# No such word
# Vogt
# No such word
# Medical
# No such word
# 2,000
# No such word
# x
# No such word
# 60,00
# No such word
# 120,00
# No such word
# Стоимость
# No such word
# 120,00
# No such word
# 5.
# No such word
# Naturella
# No such word
# прокладки
# No such word
# Классик
# No such word
# макси
# No such word
# №8
# No such word
# 1,000
# No such word
# x
# No such word
# 310,00
# No such word
# 310,00
# No such word
# Стоимость
# No such word
# 310,00
# No such word
# 6.
# No such word
# AURA
# No such word
# Ватные
# No such word
# диски
# No such word
# №150
# No such word
# 1,000
# No such word
# x
# No such word
# 461,00
# No such word
# 461,00
# No such word
# Стоимость
# No such word
# 461,00
# No such word
# 7.
# No such word
# Чистая
# No such word
# линия
# No such word
# скраб
# No such word
# мягкий
# No such word
# 50
# No such word
# мл
# No such word
# 1,000
# No such word
# x
# No such word
# 381,00
# No such word
# 381,00
# No such word
# Стоимость
# No such word
# 381,00
# No such word
# 8.
# No such word
# Чистая
# No such word
# линия
# No such word
# скраб
# No such word
# очищающийабрикос
# No such word
# 50
# No such word
# мл
# No such word
# 1,000
# No such word
# x
# No such word
# 386,00
# No such word
# 386,00
# No such word
# Стоимость
# No such word
# 386,00
# No such word
# 9.
# No such word
# Чистая
# No such word
# линия
# No such word
# скраб
# No such word
# мягкий
# No such word
# 50
# No such word
# мл
# No such word
# 1,000
# No such word
# x
# No such word
# 381,00
# No such word
# 381,00
# No such word
# Стоимость
# No such word
# 381,00
# No such word
# 10.
# No such word
# Carefree
# No such word
# салфетки
# No such word
# Алоэвоздухопроницаемые
# No such word
# №20
# No such word
# 1,000
# No such word
# x
# No such word
# 414,00
# No such word
# 414,00
# No such word
# Стоимость
# No such word
# 414,00
# No such word
# 11.
# No such word
# Pro
# No such word
# Series
# No such word
# Шампунь
# No such word
# яркий
# No such word
# цвет
# No such word
# 500мл
# No such word
# 1,000
# No such word
# x
# No such word
# 841,00
# No such word
# 841,00
# No such word
# Стоимость
# No such word
# 841,00
# No such word
# 12.
# No such word
# Pro
# No such word
# Series
# No such word
# бальзам-ополаскивательдля
# No such word
# длител
# No such word
# ухода
# No such word
# за
# No such word
# окрашеннымиволосами
# No such word
# Яркий
# No such word
# цвет
# No such word
# 500мл
# No such word
# 1,000
# No such word
# x
# No such word
# 841,00
# No such word
# 841,00
# No such word
# Стоимость
# No such word
# 841,00
# No such word
# 13.
# No such word
# Clear
# No such word
# шампунь
# No such word
# Актив
# No such word
# спорт
# No such word
# 2в1мужской
# No such word
# 400
# No such word
# мл
# No such word
# 1,000
# No such word
# x
# No such word
# 1
# No such word
# 200,00
# No such word
# 1
# No such word
# 200,00
# No such word
# Стоимость
# No such word
# 1
# No such word
# 200,00
# No such word
# 14.
# No such word
# Bio
# No such word
# World
# No such word
# (HYDRO
# No such word
# THERAPY)Мицеллярная
# No such word
# вода
# No such word
# 5в1,
# No such word
# 445мл
# No such word
# 1,000
# No such word
# x
# No such word
# 1
# No such word
# 152,00
# No such word
# 1
# No such word
# 152,00
# No such word
# Стоимость
# No such word
# 1
# No such word
# 152,00
# No such word
# 15.
# No such word
# Bio
# No such word
# World
# No such word
# (HYDRO
# No such word
# THERAPY)
# No such word
# Гель-муссдля
# No such word
# умывания
# No such word
# с
# No such word
# гиалуроновойкислотой,
# No such word
# 250мл
# No such word
# 1,000
# No such word
# x
# No such word
# 1
# No such word
# 152,00
# No such word
# 1
# No such word
# 152,00
# No such word
# Стоимость
# No such word
# 1
# No such word
# 152,00
# No such word
# 16.
# No such word
# [RX]-Натрия
# No such word
# хлорид
# No such word
# 0,9%,
# No such word
# 100
# No such word
# мл,
# No such word
# фл.
# No such word
# 1,000
# No such word
# x
# No such word
# 168,00
# No such word
# 168,00
# No such word
# Стоимость
# No such word
# 168,00
# No such word
# 17.
# No such word
# [RX]-Дисоль
# No such word
# р-р
# No such word
# 400
# No such word
# мл,
# No such word
# фл.
# No such word
# 1,000
# No such word
# x
# No such word
# 163,00
# No such word
# 163,00
# No such word
# Стоимость
# No such word
# 163,00
# No such word
# 18.
# No such word
# Тагансорбент
# No such word
# с
# No such word
# иономи
# No such word
# серебра
# No such word
# №30,пор.
# No such word
# 1,000
# No such word
# x
# No such word
# 1
# No such word
# 526,00
# No such word
# 1
# No such word
# 526,00
# No such word
# Стоимость
# No such word
# 1
# No such word
# 526,00
# No such word
# 19.
# No such word
# [RX]-Церукал
# No such word
# 2%,
# No such word
# 2
# No such word
# мл,
# No such word
# №10,
# No such word
# амп.
# No such word
# 2,000
# No such word
# x
# No such word
# 396,00
# No such word
# 792,00
# No such word
# Стоимость
# No such word
# 792,00
# No such word
# 20.
# No such word
# [RX]-Андазол
# No such word
# 200
# No such word
# мг,
# No such word
# №40,
# No such word
# табл.
# No such word
# 1,000
# No such word
# x
# No such word
# 7
# No such word
# 330,00
# No such word
# 7
# No such word
# 330,00
# No such word
# Стоимость
# No such word
# 7
# No such word
# 330,00
# No such word
# Банковская
# No such word
# карта:
# No such word
# 18
# No such word
# 009,00
# No such word
# ИТОГО:
# No such word
# 18
# No such word
# 009,00
# No such word
# в
# No such word
# т.ч.
# No such word
# НДС
# No such word
# 12%:
# No such word
# 0,00
# No such word
# Фискальный
# No such word
# признак:
# No such word
# 2331180266
# No such word
# Время:
# No such word
# 18.04.2019
# No such word
# 11:13:58
# No such word
# г.
# No such word
# Нур-султан,Казахстан,
# No such word
# Мангилик
# No such word
# Ел,19,
# No such word
# нп-5
# No such word
# Оператор
# No such word
# фискальных
# No such word
# данных:
# No such word
# АО"Казахтелеком"Для
# No such word
# проверки
# No such word
# чека
# No such word
# зайдите
# No such word
# на
# No such word
# сайт:consumer.oofd.kz
# No such word
# ФИСКАЛЬНЫЙ
# No such word
# ЧЕК
# No such word
# ФП
# No such word
# ИНК
# No such word
# ОФД:
# No such word
# 311559
# No such word
# Код
# No such word
# ККМ
# No such word
# КГД
# No such word
# (РНМ):
# No such word
# 620300145316
# No such word
# ЗНМ:
# No such word
# SWK00034961
# No such word
# WEBKASSA.KZ
# No such word
# абб
# абб

# %%
import re
f = open("row.txt")
pattern = re.compile(r"([а-я]+_)+[а-я]+")
for i in f.readlines():
    for j in i.split():
        print(j)
        match = pattern.match(j)
        if match: print(match.group())
        else: print("No such word")
# Out:
# ДУБЛИКАТ
# No such word
# Филиал
# No such word
# ТОО
# No such word
# EUROPHARMA
# No such word
# Астана
# No such word
# БИН
# No such word
# 080841000761
# No such word
# НДС
# No such word
# Серия
# No such word
# 58001
# No such word
# №
# No such word
# 0014377
# No such word
# Касса
# No such word
# 300-189
# No such word
# Смена
# No such word
# 10
# No such word
# Порядковый
# No such word
# номер
# No such word
# чека
# No such word
# №64
# No such word
# Чек
# No such word
# №2331180266
# No such word
# Кассир
# No such word
# Аптека
# No such word
# 17-1
# No such word
# ПРОДАЖА
# No such word
# 1.
# No such word
# Натрия
# No such word
# хлорид
# No such word
# 0,9%,
# No such word
# 200
# No such word
# мл,
# No such word
# фл
# No such word
# 2,000
# No such word
# x
# No such word
# 154,00
# No such word
# 308,00
# No such word
# Стоимость
# No such word
# 308,00
# No such word
# 2.
# No such word
# Борный
# No such word
# спирт
# No such word
# 3%,
# No such word
# 20
# No such word
# мл,
# No such word
# фл.
# No such word
# 1,000
# No such word
# x
# No such word
# 51,00
# No such word
# 51,00
# No such word
# Стоимость
# No such word
# 51,00
# No such word
# 3.
# No such word
# Шприц
# No such word
# 2
# No such word
# мл,
# No such word
# 3-х
# No such word
# комп.
# No such word
# (Bioject)
# No such word
# 2,000
# No such word
# x
# No such word
# 16,00
# No such word
# 32,00
# No such word
# Стоимость
# No such word
# 32,00
# No such word
# 4.
# No such word
# Система
# No such word
# для
# No such word
# инфузии
# No such word
# Vogt
# No such word
# Medical
# No such word
# 2,000
# No such word
# x
# No such word
# 60,00
# No such word
# 120,00
# No such word
# Стоимость
# No such word
# 120,00
# No such word
# 5.
# No such word
# Naturella
# No such word
# прокладки
# No such word
# Классик
# No such word
# макси
# No such word
# №8
# No such word
# 1,000
# No such word
# x
# No such word
# 310,00
# No such word
# 310,00
# No such word
# Стоимость
# No such word
# 310,00
# No such word
# 6.
# No such word
# AURA
# No such word
# Ватные
# No such word
# диски
# No such word
# №150
# No such word
# 1,000
# No such word
# x
# No such word
# 461,00
# No such word
# 461,00
# No such word
# Стоимость
# No such word
# 461,00
# No such word
# 7.
# No such word
# Чистая
# No such word
# линия
# No such word
# скраб
# No such word
# мягкий
# No such word
# 50
# No such word
# мл
# No such word
# 1,000
# No such word
# x
# No such word
# 381,00
# No such word
# 381,00
# No such word
# Стоимость
# No such word
# 381,00
# No such word
# 8.
# No such word
# Чистая
# No such word
# линия
# No such word
# скраб
# No such word
# очищающийабрикос
# No such word
# 50
# No such word
# мл
# No such word
# 1,000
# No such word
# x
# No such word
# 386,00
# No such word
# 386,00
# No such word
# Стоимость
# No such word
# 386,00
# No such word
# 9.
# No such word
# Чистая
# No such word
# линия
# No such word
# скраб
# No such word
# мягкий
# No such word
# 50
# No such word
# мл
# No such word
# 1,000
# No such word
# x
# No such word
# 381,00
# No such word
# 381,00
# No such word
# Стоимость
# No such word
# 381,00
# No such word
# 10.
# No such word
# Carefree
# No such word
# салфетки
# No such word
# Алоэвоздухопроницаемые
# No such word
# №20
# No such word
# 1,000
# No such word
# x
# No such word
# 414,00
# No such word
# 414,00
# No such word
# Стоимость
# No such word
# 414,00
# No such word
# 11.
# No such word
# Pro
# No such word
# Series
# No such word
# Шампунь
# No such word
# яркий
# No such word
# цвет
# No such word
# 500мл
# No such word
# 1,000
# No such word
# x
# No such word
# 841,00
# No such word
# 841,00
# No such word
# Стоимость
# No such word
# 841,00
# No such word
# 12.
# No such word
# Pro
# No such word
# Series
# No such word
# бальзам-ополаскивательдля
# No such word
# длител
# No such word
# ухода
# No such word
# за
# No such word
# окрашеннымиволосами
# No such word
# Яркий
# No such word
# цвет
# No such word
# 500мл
# No such word
# 1,000
# No such word
# x
# No such word
# 841,00
# No such word
# 841,00
# No such word
# Стоимость
# No such word
# 841,00
# No such word
# 13.
# No such word
# Clear
# No such word
# шампунь
# No such word
# Актив
# No such word
# спорт
# No such word
# 2в1мужской
# No such word
# 400
# No such word
# мл
# No such word
# 1,000
# No such word
# x
# No such word
# 1
# No such word
# 200,00
# No such word
# 1
# No such word
# 200,00
# No such word
# Стоимость
# No such word
# 1
# No such word
# 200,00
# No such word
# 14.
# No such word
# Bio
# No such word
# World
# No such word
# (HYDRO
# No such word
# THERAPY)Мицеллярная
# No such word
# вода
# No such word
# 5в1,
# No such word
# 445мл
# No such word
# 1,000
# No such word
# x
# No such word
# 1
# No such word
# 152,00
# No such word
# 1
# No such word
# 152,00
# No such word
# Стоимость
# No such word
# 1
# No such word
# 152,00
# No such word
# 15.
# No such word
# Bio
# No such word
# World
# No such word
# (HYDRO
# No such word
# THERAPY)
# No such word
# Гель-муссдля
# No such word
# умывания
# No such word
# с
# No such word
# гиалуроновойкислотой,
# No such word
# 250мл
# No such word
# 1,000
# No such word
# x
# No such word
# 1
# No such word
# 152,00
# No such word
# 1
# No such word
# 152,00
# No such word
# Стоимость
# No such word
# 1
# No such word
# 152,00
# No such word
# 16.
# No such word
# [RX]-Натрия
# No such word
# хлорид
# No such word
# 0,9%,
# No such word
# 100
# No such word
# мл,
# No such word
# фл.
# No such word
# 1,000
# No such word
# x
# No such word
# 168,00
# No such word
# 168,00
# No such word
# Стоимость
# No such word
# 168,00
# No such word
# 17.
# No such word
# [RX]-Дисоль
# No such word
# р-р
# No such word
# 400
# No such word
# мл,
# No such word
# фл.
# No such word
# 1,000
# No such word
# x
# No such word
# 163,00
# No such word
# 163,00
# No such word
# Стоимость
# No such word
# 163,00
# No such word
# 18.
# No such word
# Тагансорбент
# No such word
# с
# No such word
# иономи
# No such word
# серебра
# No such word
# №30,пор.
# No such word
# 1,000
# No such word
# x
# No such word
# 1
# No such word
# 526,00
# No such word
# 1
# No such word
# 526,00
# No such word
# Стоимость
# No such word
# 1
# No such word
# 526,00
# No such word
# 19.
# No such word
# [RX]-Церукал
# No such word
# 2%,
# No such word
# 2
# No such word
# мл,
# No such word
# №10,
# No such word
# амп.
# No such word
# 2,000
# No such word
# x
# No such word
# 396,00
# No such word
# 792,00
# No such word
# Стоимость
# No such word
# 792,00
# No such word
# 20.
# No such word
# [RX]-Андазол
# No such word
# 200
# No such word
# мг,
# No such word
# №40,
# No such word
# табл.
# No such word
# 1,000
# No such word
# x
# No such word
# 7
# No such word
# 330,00
# No such word
# 7
# No such word
# 330,00
# No such word
# Стоимость
# No such word
# 7
# No such word
# 330,00
# No such word
# Банковская
# No such word
# карта:
# No such word
# 18
# No such word
# 009,00
# No such word
# ИТОГО:
# No such word
# 18
# No such word
# 009,00
# No such word
# в
# No such word
# т.ч.
# No such word
# НДС
# No such word
# 12%:
# No such word
# 0,00
# No such word
# Фискальный
# No such word
# признак:
# No such word
# 2331180266
# No such word
# Время:
# No such word
# 18.04.2019
# No such word
# 11:13:58
# No such word
# г.
# No such word
# Нур-султан,Казахстан,
# No such word
# Мангилик
# No such word
# Ел,19,
# No such word
# нп-5
# No such word
# Оператор
# No such word
# фискальных
# No such word
# данных:
# No such word
# АО"Казахтелеком"Для
# No such word
# проверки
# No such word
# чека
# No such word
# зайдите
# No such word
# на
# No such word
# сайт:consumer.oofd.kz
# No such word
# ФИСКАЛЬНЫЙ
# No such word
# ЧЕК
# No such word
# ФП
# No such word
# ИНК
# No such word
# ОФД:
# No such word
# 311559
# No such word
# Код
# No such word
# ККМ
# No such word
# КГД
# No such word
# (РНМ):
# No such word
# 620300145316
# No such word
# ЗНМ:
# No such word
# SWK00034961
# No such word
# WEBKASSA.KZ
# No such word
# а_б
# а_б

# %%
import re
f = open("row.txt")
pattern = re.compile(r".*а.*б")
for i in f.readlines():
    for j in i.split():
        print(j)
        match = pattern.match(j)
        if match: print(match.group())
        else: print("No such word")
# Out:
# ДУБЛИКАТ
# No such word
# Филиал
# No such word
# ТОО
# No such word
# EUROPHARMA
# No such word
# Астана
# No such word
# БИН
# No such word
# 080841000761
# No such word
# НДС
# No such word
# Серия
# No such word
# 58001
# No such word
# №
# No such word
# 0014377
# No such word
# Касса
# No such word
# 300-189
# No such word
# Смена
# No such word
# 10
# No such word
# Порядковый
# No such word
# номер
# No such word
# чека
# No such word
# №64
# No such word
# Чек
# No such word
# №2331180266
# No such word
# Кассир
# No such word
# Аптека
# No such word
# 17-1
# No such word
# ПРОДАЖА
# No such word
# 1.
# No such word
# Натрия
# No such word
# хлорид
# No such word
# 0,9%,
# No such word
# 200
# No such word
# мл,
# No such word
# фл
# No such word
# 2,000
# No such word
# x
# No such word
# 154,00
# No such word
# 308,00
# No such word
# Стоимость
# No such word
# 308,00
# No such word
# 2.
# No such word
# Борный
# No such word
# спирт
# No such word
# 3%,
# No such word
# 20
# No such word
# мл,
# No such word
# фл.
# No such word
# 1,000
# No such word
# x
# No such word
# 51,00
# No such word
# 51,00
# No such word
# Стоимость
# No such word
# 51,00
# No such word
# 3.
# No such word
# Шприц
# No such word
# 2
# No such word
# мл,
# No such word
# 3-х
# No such word
# комп.
# No such word
# (Bioject)
# No such word
# 2,000
# No such word
# x
# No such word
# 16,00
# No such word
# 32,00
# No such word
# Стоимость
# No such word
# 32,00
# No such word
# 4.
# No such word
# Система
# No such word
# для
# No such word
# инфузии
# No such word
# Vogt
# No such word
# Medical
# No such word
# 2,000
# No such word
# x
# No such word
# 60,00
# No such word
# 120,00
# No such word
# Стоимость
# No such word
# 120,00
# No such word
# 5.
# No such word
# Naturella
# No such word
# прокладки
# No such word
# Классик
# No such word
# макси
# No such word
# №8
# No such word
# 1,000
# No such word
# x
# No such word
# 310,00
# No such word
# 310,00
# No such word
# Стоимость
# No such word
# 310,00
# No such word
# 6.
# No such word
# AURA
# No such word
# Ватные
# No such word
# диски
# No such word
# №150
# No such word
# 1,000
# No such word
# x
# No such word
# 461,00
# No such word
# 461,00
# No such word
# Стоимость
# No such word
# 461,00
# No such word
# 7.
# No such word
# Чистая
# No such word
# линия
# No such word
# скраб
# скраб
# мягкий
# No such word
# 50
# No such word
# мл
# No such word
# 1,000
# No such word
# x
# No such word
# 381,00
# No such word
# 381,00
# No such word
# Стоимость
# No such word
# 381,00
# No such word
# 8.
# No such word
# Чистая
# No such word
# линия
# No such word
# скраб
# скраб
# очищающийабрикос
# очищающийаб
# 50
# No such word
# мл
# No such word
# 1,000
# No such word
# x
# No such word
# 386,00
# No such word
# 386,00
# No such word
# Стоимость
# No such word
# 386,00
# No such word
# 9.
# No such word
# Чистая
# No such word
# линия
# No such word
# скраб
# скраб
# мягкий
# No such word
# 50
# No such word
# мл
# No such word
# 1,000
# No such word
# x
# No such word
# 381,00
# No such word
# 381,00
# No such word
# Стоимость
# No such word
# 381,00
# No such word
# 10.
# No such word
# Carefree
# No such word
# салфетки
# No such word
# Алоэвоздухопроницаемые
# No such word
# №20
# No such word
# 1,000
# No such word
# x
# No such word
# 414,00
# No such word
# 414,00
# No such word
# Стоимость
# No such word
# 414,00
# No such word
# 11.
# No such word
# Pro
# No such word
# Series
# No such word
# Шампунь
# No such word
# яркий
# No such word
# цвет
# No such word
# 500мл
# No such word
# 1,000
# No such word
# x
# No such word
# 841,00
# No such word
# 841,00
# No such word
# Стоимость
# No such word
# 841,00
# No such word
# 12.
# No such word
# Pro
# No such word
# Series
# No such word
# бальзам-ополаскивательдля
# No such word
# длител
# No such word
# ухода
# No such word
# за
# No such word
# окрашеннымиволосами
# No such word
# Яркий
# No such word
# цвет
# No such word
# 500мл
# No such word
# 1,000
# No such word
# x
# No such word
# 841,00
# No such word
# 841,00
# No such word
# Стоимость
# No such word
# 841,00
# No such word
# 13.
# No such word
# Clear
# No such word
# шампунь
# No such word
# Актив
# No such word
# спорт
# No such word
# 2в1мужской
# No such word
# 400
# No such word
# мл
# No such word
# 1,000
# No such word
# x
# No such word
# 1
# No such word
# 200,00
# No such word
# 1
# No such word
# 200,00
# No such word
# Стоимость
# No such word
# 1
# No such word
# 200,00
# No such word
# 14.
# No such word
# Bio
# No such word
# World
# No such word
# (HYDRO
# No such word
# THERAPY)Мицеллярная
# No such word
# вода
# No such word
# 5в1,
# No such word
# 445мл
# No such word
# 1,000
# No such word
# x
# No such word
# 1
# No such word
# 152,00
# No such word
# 1
# No such word
# 152,00
# No such word
# Стоимость
# No such word
# 1
# No such word
# 152,00
# No such word
# 15.
# No such word
# Bio
# No such word
# World
# No such word
# (HYDRO
# No such word
# THERAPY)
# No such word
# Гель-муссдля
# No such word
# умывания
# No such word
# с
# No such word
# гиалуроновойкислотой,
# No such word
# 250мл
# No such word
# 1,000
# No such word
# x
# No such word
# 1
# No such word
# 152,00
# No such word
# 1
# No such word
# 152,00
# No such word
# Стоимость
# No such word
# 1
# No such word
# 152,00
# No such word
# 16.
# No such word
# [RX]-Натрия
# No such word
# хлорид
# No such word
# 0,9%,
# No such word
# 100
# No such word
# мл,
# No such word
# фл.
# No such word
# 1,000
# No such word
# x
# No such word
# 168,00
# No such word
# 168,00
# No such word
# Стоимость
# No such word
# 168,00
# No such word
# 17.
# No such word
# [RX]-Дисоль
# No such word
# р-р
# No such word
# 400
# No such word
# мл,
# No such word
# фл.
# No such word
# 1,000
# No such word
# x
# No such word
# 163,00
# No such word
# 163,00
# No such word
# Стоимость
# No such word
# 163,00
# No such word
# 18.
# No such word
# Тагансорбент
# Тагансорб
# с
# No such word
# иономи
# No such word
# серебра
# No such word
# №30,пор.
# No such word
# 1,000
# No such word
# x
# No such word
# 1
# No such word
# 526,00
# No such word
# 1
# No such word
# 526,00
# No such word
# Стоимость
# No such word
# 1
# No such word
# 526,00
# No such word
# 19.
# No such word
# [RX]-Церукал
# No such word
# 2%,
# No such word
# 2
# No such word
# мл,
# No such word
# №10,
# No such word
# амп.
# No such word
# 2,000
# No such word
# x
# No such word
# 396,00
# No such word
# 792,00
# No such word
# Стоимость
# No such word
# 792,00
# No such word
# 20.
# No such word
# [RX]-Андазол
# No such word
# 200
# No such word
# мг,
# No such word
# №40,
# No such word
# табл.
# таб
# 1,000
# No such word
# x
# No such word
# 7
# No such word
# 330,00
# No such word
# 7
# No such word
# 330,00
# No such word
# Стоимость
# No such word
# 7
# No such word
# 330,00
# No such word
# Банковская
# No such word
# карта:
# No such word
# 18
# No such word
# 009,00
# No such word
# ИТОГО:
# No such word
# 18
# No such word
# 009,00
# No such word
# в
# No such word
# т.ч.
# No such word
# НДС
# No such word
# 12%:
# No such word
# 0,00
# No such word
# Фискальный
# No such word
# признак:
# No such word
# 2331180266
# No such word
# Время:
# No such word
# 18.04.2019
# No such word
# 11:13:58
# No such word
# г.
# No such word
# Нур-султан,Казахстан,
# No such word
# Мангилик
# No such word
# Ел,19,
# No such word
# нп-5
# No such word
# Оператор
# No such word
# фискальных
# No such word
# данных:
# No such word
# АО"Казахтелеком"Для
# No such word
# проверки
# No such word
# чека
# No such word
# зайдите
# No such word
# на
# No such word
# сайт:consumer.oofd.kz
# No such word
# ФИСКАЛЬНЫЙ
# No such word
# ЧЕК
# No such word
# ФП
# No such word
# ИНК
# No such word
# ОФД:
# No such word
# 311559
# No such word
# Код
# No such word
# ККМ
# No such word
# КГД
# No such word
# (РНМ):
# No such word
# 620300145316
# No such word
# ЗНМ:
# No such word
# SWK00034961
# No such word
# WEBKASSA.KZ
# No such word
# а_б
# а_б
